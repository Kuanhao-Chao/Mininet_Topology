# %%
from mininet.topo import Topo
from mininet.util import irange
from mininet.cli  import CLI
from mininet.net import Mininet
from mininet.node import OVSSwitch, Controller, RemoteController
from mininet.log import setLogLevel, info

# %%
# info( "*** Creating (reference) controllers\n" )
# c1 = net.addController( 'c1', port=6633 )
# c2 = net.addController( 'c2', port=6634 )

# %%
def parseFile():
    line_number = 1
    with open('connection_data_100.csv') as f:
        for each_line in f:
            if(line_number == 1):
#                 print(line_number)
                global list_node
                list_node = each_line.split()
                line_number += 1
#                 print(each_line)
            else:
#                 print(line_number)
                each_link = each_line.split()
                list_link.append(each_link)
                line_number += 1
#                 print(each_line)
#     print(list_node)          
#     print(list_link)

# %%
class custom_topo(Topo):
    "Configurable Datacenter Topology"
    
    def build(self):
        global host_node_list
        global switch_node_list
        global list_link

        flag = True
        for i in list_node:
            for j in i:
                if(j == 'h'):
                    host_node_list.append(i)
                    print(i)
                    flag = False
                    break
            if(flag == True):
                switch_node_list.append(i)
#                 print(i)
        print(host_node_list)
        print(switch_node_list)
        
        for i in host_node_list:
#             info( "*** Creating switches\n" )
            self.addHost(i)
        for i in switch_node_list:
#             info( "*** Creating hosts\n" )
            self.addSwitch(i)
        for x in list_link:
#             info( "*** Adding links\n" )
            self.addLink(x[0], x[1])
            print(x)

# %%
def runNet():
    "Create and run the network"
    info( "*** Starting network\n" )
    topo = custom_topo()
    net = Mininet( topo = topo, controller=Controller, switch=OVSSwitch, )
    net.start()
    CLI(net)

# %%
if __name__ == '__main__':
    setLogLevel( 'info' )
    list_node = []
    list_link = []
    host_node_list = []
    switch_node_list = []
    
    parseFile()
#     print(list_node)          
#     print(list_link)
    runNet()
# Out:
# *** Starting network
# *** Creating network
# *** Adding controller
# ssh0
# ssh1
# ssh2
# ssh3
# ssh4
# ssh5
# ssh6
# ssh7
# ssh8
# ssh9
# ssh10
# ssh11
# ssh12
# ssh13
# ssh14
# ssh15
# ssh16
# ssh17
# ssh18
# ssh19
# ssh20
# ssh21
# ssh22
# ssh23
# ssh24
# ssh25
# ssh26
# ssh27
# ssh28
# ssh29
# ssh30
# ssh31
# ssh32
# ssh33
# ssh34
# ssh35
# ssh36
# ssh37
# ssh38
# ssh39
# ssh40
# ssh41
# ssh42
# ssh43
# ssh44
# ssh45
# ssh46
# ssh47
# ssh48
# ssh49
# ssh50
# ssh51
# ssh52
# ssh53
# ssh54
# ssh55
# ssh56
# ssh57
# ssh58
# ssh59
# ssh60
# ssh61
# ssh62
# ssh63
# ssh64
# ssh65
# ssh66
# ssh67
# ssh68
# ssh69
# ssh70
# ssh71
# ssh72
# ssh73
# ssh74
# ssh75
# ssh76
# ssh77
# ssh78
# ssh79
# ssh80
# ssh81
# ssh82
# ssh83
# ssh84
# ssh85
# ssh86
# ssh87
# ssh88
# ssh89
# ssh90
# ssh91
# ssh92
# ssh93
# ssh94
# ssh95
# ssh96
# ssh97
# ssh98
# ssh99
# ['ssh0', 'ssh1', 'ssh2', 'ssh3', 'ssh4', 'ssh5', 'ssh6', 'ssh7', 'ssh8', 'ssh9', 'ssh10', 'ssh11', 'ssh12', 'ssh13', 'ssh14', 'ssh15', 'ssh16', 'ssh17', 'ssh18', 'ssh19', 'ssh20', 'ssh21', 'ssh22', 'ssh23', 'ssh24', 'ssh25', 'ssh26', 'ssh27', 'ssh28', 'ssh29', 'ssh30', 'ssh31', 'ssh32', 'ssh33', 'ssh34', 'ssh35', 'ssh36', 'ssh37', 'ssh38', 'ssh39', 'ssh40', 'ssh41', 'ssh42', 'ssh43', 'ssh44', 'ssh45', 'ssh46', 'ssh47', 'ssh48', 'ssh49', 'ssh50', 'ssh51', 'ssh52', 'ssh53', 'ssh54', 'ssh55', 'ssh56', 'ssh57', 'ssh58', 'ssh59', 'ssh60', 'ssh61', 'ssh62', 'ssh63', 'ssh64', 'ssh65', 'ssh66', 'ssh67', 'ssh68', 'ssh69', 'ssh70', 'ssh71', 'ssh72', 'ssh73', 'ssh74', 'ssh75', 'ssh76', 'ssh77', 'ssh78', 'ssh79', 'ssh80', 'ssh81', 'ssh82', 'ssh83', 'ssh84', 'ssh85', 'ssh86', 'ssh87', 'ssh88', 'ssh89', 'ssh90', 'ssh91', 'ssh92', 'ssh93', 'ssh94', 'ssh95', 'ssh96', 'ssh97', 'ssh98', 'ssh99']
# ['s0', 's1', 's2', 's3', 's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 'ss0', 'ss1', 'ss2', 'ss3', 'ss4', 'ss5', 'ss6', 'ss7', 'ss8', 'ss9', 'ss10', 'ss11', 'ss12', 'ss13', 'ss14', 'ss15', 'ss16', 'ss17', 'ss18', 'ss19', 'ss20', 'ss21', 'ss22', 'ss23', 'ss24', 'ss25', 'ss26', 'ss27', 'ss28', 'ss29', 'ss30', 'ss31', 'ss32', 'ss33', 'ss34', 'ss35', 'ss36', 'ss37', 'ss38', 'ss39', 'ss40', 'ss41', 'ss42', 'ss43', 'ss44', 'ss45', 'ss46', 'ss47', 'ss48', 'ss49', 'ss50', 'ss51', 'ss52', 'ss53', 'ss54', 'ss55', 'ss56', 'ss57', 'ss58', 'ss59', 'ss60', 'ss61', 'ss62', 'ss63', 'ss64', 'ss65', 'ss66', 'ss67', 'ss68', 'ss69', 'ss70', 'ss71', 'ss72', 'ss73', 'ss74', 'ss75', 'ss76', 'ss77', 'ss78', 'ss79', 'ss80', 'ss81', 'ss82', 'ss83', 'ss84', 'ss85', 'ss86', 'ss87', 'ss88', 'ss89', 'ss90', 'ss91', 'ss92', 'ss93', 'ss94', 'ss95', 'ss96', 'ss97', 'ss98', 'ss99']
# ['s0', 's1', '100']
# ['s0', 's2', '100']
# ['s0', 's3', '100']
# ['s1', 's4', '100']
# ['s0', 's5', '100']
# ['s4', 's6', '100']
# ['s5', 's7', '100']
# ['s4', 's8', '100']
# ['s4', 's9', '100']
# ['s4', 's10', '100']
# ['s2', 's10', '100']
# ['s4', 's11', '100']
# ['s1', 's11', '100']
# ['s9', 's12', '100']
# ['s4', 's13', '100']
# ['s7', 's14', '100']
# ['s2', 's14', '100']
# ['s7', 's15', '100']
# ['s10', 's15', '100']
# ['s4', 's16', '100']
# ['s2', 's16', '100']
# ['s15', 's17', '100']
# ['s4', 's18', '100']
# ['s13', 's18', '100']
# ['s15', 's19', '100']
# ['s18', 's20', '100']
# ['s0', 'ss22', '100']
# ['s0', 'ss31', '100']
# ['s0', 'ss97', '100']
# ['s1', 'ss51', '100']
# ['s1', 'ss65', '100']
# ['s1', 'ss90', '100']
# ['s4', 'ss31', '100']
# ['s4', 'ss37', '100']
# ['s4', 'ss60', '100']
# ['s4', 'ss77', '100']
# ['s4', 'ss81', '100']
# ['s5', 'ss69', '100']
# ['s6', 'ss66', '100']
# ['s9', 'ss57', '100']
# ['s10', 'ss23', '100']
# ['s10', 'ss28', '100']
# ['s10', 'ss64', '100']
# ['s10', 'ss82', '100']
# ['s10', 'ss92', '100']
# ['s10', 'ss94', '100']
# ['s11', 'ss25', '100']
# ['s12', 'ss85', '100']
# ['s13', 'ss47', '100']
# ['s13', 'ss91', '100']
# ['s14', 'ss21', '100']
# ['s14', 'ss68', '100']
# ['s16', 'ss73', '100']
# ['s18', 'ss87', '100']
# ['s20', 'ss86', '100']
# ['s20', 'ss87', '100']
# ['ss21', 'ss14', '100']
# ['ss21', 'ss22', '100']
# ['ss21', 'ss35', '100']
# ['ss21', 'ss57', '100']
# ['ss21', 'ss60', '100']
# ['ss21', 'ss75', '100']
# ['ss21', 'ss77', '100']
# ['ss21', 'ss80', '100']
# ['ss21', 'ss81', '100']
# ['ss21', 'ss86', '100']
# ['ss21', 'ss97', '100']
# ['ss22', 'ss3', '100']
# ['ss22', 'ss35', '100']
# ['ss22', 'ss51', '100']
# ['ss28', 'ss13', '100']
# ['ss28', 'ss47', '100']
# ['ss28', 'ss82', '100']
# ['ss28', 'ss98', '100']
# ['ss31', 'ss19', '100']
# ['ss31', 'ss29', '100']
# ['ss31', 'ss39', '100']
# ['ss31', 'ss64', '100']
# ['ss31', 'ss90', '100']
# ['ss35', 'ss14', '100']
# ['ss35', 'ss16', '100']
# ['ss35', 'ss32', '100']
# ['ss35', 'ss44', '100']
# ['ss35', 'ss78', '100']
# ['ss35', 'ss98', '100']
# ['ss37', 'ss31', '100']
# ['ss39', 'ss45', '100']
# ['ss44', 'ss83', '100']
# ['ss45', 'ss56', '100']
# ['ss45', 'ss86', '100']
# ['ss47', 'ss61', '100']
# ['ss47', 'ss82', '100']
# ['ss47', 'ss95', '100']
# ['ss51', 'ss13', '100']
# ['ss51', 'ss47', '100']
# ['ss51', 'ss53', '100']
# ['ss51', 'ss54', '100']
# ['ss51', 'ss61', '100']
# ['ss51', 'ss69', '100']
# ['ss51', 'ss73', '100']
# ['ss51', 'ss74', '100']
# ['ss51', 'ss80', '100']
# ['ss51', 'ss87', '100']
# ['ss51', 'ss97', '100']
# ['ss51', 'ss98', '100']
# ['ss53', 'ss0', '100']
# ['ss53', 'ss13', '100']
# ['ss53', 'ss18', '100']
# ['ss53', 'ss64', '100']
# ['ss53', 'ss67', '100']
# ['ss53', 'ss70', '100']
# ['ss53', 'ss74', '100']
# ['ss53', 'ss83', '100']
# ['ss53', 'ss85', '100']
# ['ss53', 'ss88', '100']
# ['ss53', 'ss93', '100']
# ['ss53', 'ss97', '100']
# ['ss54', 'ss67', '100']
# ['ss56', 'ss27', '100']
# ['ss56', 'ss38', '100']
# ['ss56', 'ss43', '100']
# ['ss56', 'ss63', '100']
# ['ss56', 'ss66', '100']
# ['ss56', 'ss90', '100']
# ['ss56', 'ss97', '100']
# ['ss57', 'ss53', '100']
# ['ss57', 'ss55', '100']
# ['ss57', 'ss74', '100']
# ['ss60', 'ss16', '100']
# ['ss60', 'ss57', '100']
# ['ss61', 'ss23', '100']
# ['ss61', 'ss47', '100']
# ['ss61', 'ss50', '100']
# ['ss61', 'ss55', '100']
# ['ss61', 'ss62', '100']
# ['ss61', 'ss85', '100']
# ['ss61', 'ss92', '100']
# ['ss61', 'ss94', '100']
# ['ss61', 'ss98', '100']
# ['ss61', 'ss99', '100']
# ['ss63', 'ss14', '100']
# ['ss63', 'ss43', '100']
# ['ss63', 'ss56', '100']
# ['ss63', 'ss84', '100']
# ['ss64', 'ss12', '100']
# ['ss64', 'ss24', '100']
# ['ss64', 'ss25', '100']
# ['ss64', 'ss41', '100']
# ['ss64', 'ss49', '100']
# ['ss64', 'ss58', '100']
# ['ss64', 'ss68', '100']
# ['ss64', 'ss70', '100']
# ['ss64', 'ss72', '100']
# ['ss64', 'ss74', '100']
# ['ss64', 'ss75', '100']
# ['ss64', 'ss83', '100']
# ['ss64', 'ss89', '100']
# ['ss64', 'ss96', '100']
# ['ss65', 'ss9', '100']
# ['ss66', 'ss9', '100']
# ['ss66', 'ss10', '100']
# ['ss66', 'ss54', '100']
# ['ss66', 'ss73', '100']
# ['ss66', 'ss88', '100']
# ['ss67', 'ss10', '100']
# ['ss67', 'ss39', '100']
# ['ss67', 'ss66', '100']
# ['ss67', 'ss69', '100']
# ['ss67', 'ss77', '100']
# ['ss67', 'ss86', '100']
# ['ss67', 'ss93', '100']
# ['ss68', 'ss71', '100']
# ['ss69', 'ss24', '100']
# ['ss69', 'ss67', '100']
# ['ss69', 'ss96', '100']
# ['ss71', 'ss85', '100']
# ['ss72', 'ss39', '100']
# ['ss73', 'ss51', '100']
# ['ss73', 'ss61', '100']
# ['ss73', 'ss82', '100']
# ['ss73', 'ss98', '100']
# ['ss74', 'ss3', '100']
# ['ss74', 'ss26', '100']
# ['ss74', 'ss37', '100']
# ['ss74', 'ss43', '100']
# ['ss74', 'ss53', '100']
# ['ss74', 'ss57', '100']
# ['ss74', 'ss82', '100']
# ['ss75', 'ss64', '100']
# ['ss77', 'ss19', '100']
# ['ss77', 'ss21', '100']
# ['ss77', 'ss31', '100']
# ['ss77', 'ss33', '100']
# ['ss77', 'ss35', '100']
# ['ss77', 'ss37', '100']
# ['ss77', 'ss38', '100']
# ['ss77', 'ss54', '100']
# ['ss77', 'ss56', '100']
# ['ss77', 'ss62', '100']
# ['ss77', 'ss63', '100']
# ['ss77', 'ss67', '100']
# ['ss77', 'ss80', '100']
# ['ss77', 'ss81', '100']
# ['ss77', 'ss82', '100']
# ['ss77', 'ss94', '100']
# ['ss78', 'ss17', '100']
# ['ss78', 'ss33', '100']
# ['ss78', 'ss65', '100']
# ['ss78', 'ss66', '100']
# ['ss78', 'ss85', '100']
# ['ss80', 'ss57', '100']
# ['ss80', 'ss76', '100']
# ['ss81', 'ss2', '100']
# ['ss81', 'ss14', '100']
# ['ss81', 'ss38', '100']
# ['ss81', 'ss43', '100']
# ['ss81', 'ss67', '100']
# ['ss81', 'ss73', '100']
# ['ss81', 'ss76', '100']
# ['ss81', 'ss77', '100']
# ['ss81', 'ss78', '100']
# ['ss81', 'ss93', '100']
# ['ss81', 'ss95', '100']
# ['ss81', 'ss97', '100']
# ['ss82', 'ss16', '100']
# ['ss82', 'ss40', '100']
# ['ss82', 'ss41', '100']
# ['ss82', 'ss42', '100']
# ['ss82', 'ss43', '100']
# ['ss82', 'ss47', '100']
# ['ss82', 'ss52', '100']
# ['ss82', 'ss60', '100']
# ['ss82', 'ss65', '100']
# ['ss82', 'ss74', '100']
# ['ss82', 'ss77', '100']
# ['ss82', 'ss80', '100']
# ['ss82', 'ss92', '100']
# ['ss82', 'ss94', '100']
# ['ss82', 'ss95', '100']
# ['ss83', 'ss15', '100']
# ['ss83', 'ss22', '100']
# ['ss83', 'ss37', '100']
# ['ss83', 'ss76', '100']
# ['ss83', 'ss91', '100']
# ['ss84', 'ss12', '100']
# ['ss84', 'ss18', '100']
# ['ss84', 'ss22', '100']
# ['ss84', 'ss42', '100']
# ['ss84', 'ss63', '100']
# ['ss84', 'ss66', '100']
# ['ss84', 'ss69', '100']
# ['ss84', 'ss82', '100']
# ['ss84', 'ss85', '100']
# ['ss84', 'ss86', '100']
# ['ss84', 'ss88', '100']
# ['ss85', 'ss36', '100']
# ['ss85', 'ss49', '100']
# ['ss85', 'ss87', '100']
# ['ss85', 'ss90', '100']
# ['ss85', 'ss91', '100']
# ['ss85', 'ss92', '100']
# ['ss86', 'ss2', '100']
# ['ss86', 'ss6', '100']
# ['ss86', 'ss11', '100']
# ['ss86', 'ss21', '100']
# ['ss86', 'ss26', '100']
# ['ss86', 'ss30', '100']
# ['ss86', 'ss34', '100']
# ['ss86', 'ss40', '100']
# ['ss86', 'ss43', '100']
# ['ss86', 'ss49', '100']
# ['ss86', 'ss59', '100']
# ['ss86', 'ss63', '100']
# ['ss86', 'ss73', '100']
# ['ss86', 'ss77', '100']
# ['ss86', 'ss79', '100']
# ['ss86', 'ss82', '100']
# ['ss86', 'ss84', '100']
# ['ss86', 'ss88', '100']
# ['ss86', 'ss91', '100']
# ['ss86', 'ss93', '100']
# ['ss87', 'ss40', '100']
# ['ss87', 'ss70', '100']
# ['ss88', 'ss7', '100']
# ['ss88', 'ss34', '100']
# ['ss88', 'ss53', '100']
# ['ss88', 'ss64', '100']
# ['ss88', 'ss67', '100']
# ['ss88', 'ss84', '100']
# ['ss88', 'ss87', '100']
# ['ss90', 'ss1', '100']
# ['ss90', 'ss5', '100']
# ['ss90', 'ss32', '100']
# ['ss90', 'ss42', '100']
# ['ss90', 'ss43', '100']
# ['ss90', 'ss49', '100']
# ['ss90', 'ss59', '100']
# ['ss90', 'ss65', '100']
# ['ss90', 'ss68', '100']
# ['ss90', 'ss72', '100']
# ['ss90', 'ss79', '100']
# ['ss90', 'ss87', '100']
# ['ss90', 'ss99', '100']
# ['ss91', 'ss11', '100']
# ['ss91', 'ss24', '100']
# ['ss91', 'ss31', '100']
# ['ss91', 'ss39', '100']
# ['ss91', 'ss48', '100']
# ['ss92', 'ss50', '100']
# ['ss92', 'ss63', '100']
# ['ss92', 'ss64', '100']
# ['ss92', 'ss87', '100']
# ['ss92', 'ss89', '100']
# ['ss93', 'ss9', '100']
# ['ss93', 'ss15', '100']
# ['ss93', 'ss16', '100']
# ['ss93', 'ss17', '100']
# ['ss93', 'ss19', '100']
# ['ss93', 'ss20', '100']
# ['ss93', 'ss22', '100']
# ['ss93', 'ss28', '100']
# ['ss93', 'ss32', '100']
# ['ss93', 'ss33', '100']
# ['ss93', 'ss42', '100']
# ['ss93', 'ss49', '100']
# ['ss93', 'ss63', '100']
# ['ss93', 'ss64', '100']
# ['ss93', 'ss66', '100']
# ['ss93', 'ss71', '100']
# ['ss93', 'ss72', '100']
# ['ss93', 'ss77', '100']
# ['ss93', 'ss82', '100']
# ['ss93', 'ss83', '100']
# ['ss93', 'ss85', '100']
# ['ss93', 'ss86', '100']
# ['ss93', 'ss90', '100']
# ['ss93', 'ss91', '100']
# ['ss93', 'ss95', '100']
# ['ss93', 'ss98', '100']
# ['ss94', 'ss4', '100']
# ['ss94', 'ss36', '100']
# ['ss94', 'ss42', '100']
# ['ss94', 'ss52', '100']
# ['ss94', 'ss71', '100']
# ['ss94', 'ss85', '100']
# ['ss95', 'ss47', '100']
# ['ss95', 'ss94', '100']
# ['ss96', 'ss64', '100']
# ['ss96', 'ss69', '100']
# ['ss96', 'ss70', '100']
# ['ss96', 'ss95', '100']
# ['ss97', 'ss22', '100']
# ['ss97', 'ss28', '100']
# ['ss97', 'ss32', '100']
# ['ss97', 'ss40', '100']
# ['ss97', 'ss51', '100']
# ['ss97', 'ss58', '100']
# ['ss97', 'ss64', '100']
# ['ss97', 'ss75', '100']
# ['ss97', 'ss77', '100']
# ['ss97', 'ss79', '100']
# ['ss97', 'ss84', '100']
# ['ss97', 'ss88', '100']
# ['ss97', 'ss93', '100']
# ['ss98', 'ss8', '100']
# ['ss98', 'ss13', '100']
# ['ss98', 'ss28', '100']
# ['ss98', 'ss46', '100']
# ['ss98', 'ss49', '100']
# ['ss98', 'ss50', '100']
# ['ss98', 'ss54', '100']
# ['ss98', 'ss70', '100']
# ['ss98', 'ss73', '100']
# ['ss98', 'ss82', '100']
# ['ss98', 'ss87', '100']
# ['ss98', 'ss95', '100']
# ['ss99', 'ss31', '100']
# ['ss99', 'ss51', '100']
# ['ss0', 'ssh0', '100']
# ['ss1', 'ssh1', '100']
# ['ss2', 'ssh2', '100']
# ['ss3', 'ssh3', '100']
# ['ss4', 'ssh4', '100']
# ['ss5', 'ssh5', '100']
# ['ss6', 'ssh6', '100']
# ['ss7', 'ssh7', '100']
# ['ss8', 'ssh8', '100']
# ['ss9', 'ssh9', '100']
# ['ss10', 'ssh10', '100']
# ['ss11', 'ssh11', '100']
# ['ss12', 'ssh12', '100']
# ['ss13', 'ssh13', '100']
# ['ss14', 'ssh14', '100']
# ['ss15', 'ssh15', '100']
# ['ss16', 'ssh16', '100']
# ['ss17', 'ssh17', '100']
# ['ss18', 'ssh18', '100']
# ['ss19', 'ssh19', '100']
# ['ss20', 'ssh20', '100']
# ['ss21', 'ssh21', '100']
# ['ss22', 'ssh22', '100']
# ['ss23', 'ssh23', '100']
# ['ss24', 'ssh24', '100']
# ['ss25', 'ssh25', '100']
# ['ss26', 'ssh26', '100']
# ['ss27', 'ssh27', '100']
# ['ss28', 'ssh28', '100']
# ['ss29', 'ssh29', '100']
# ['ss30', 'ssh30', '100']
# ['ss31', 'ssh31', '100']
# ['ss32', 'ssh32', '100']
# ['ss33', 'ssh33', '100']
# ['ss34', 'ssh34', '100']
# ['ss35', 'ssh35', '100']
# ['ss36', 'ssh36', '100']
# ['ss37', 'ssh37', '100']
# ['ss38', 'ssh38', '100']
# ['ss39', 'ssh39', '100']
# ['ss40', 'ssh40', '100']
# ['ss41', 'ssh41', '100']
# ['ss42', 'ssh42', '100']
# ['ss43', 'ssh43', '100']
# ['ss44', 'ssh44', '100']
# ['ss45', 'ssh45', '100']
# ['ss46', 'ssh46', '100']
# ['ss47', 'ssh47', '100']
# ['ss48', 'ssh48', '100']
# ['ss49', 'ssh49', '100']
# ['ss50', 'ssh50', '100']
# ['ss51', 'ssh51', '100']
# ['ss52', 'ssh52', '100']
# ['ss53', 'ssh53', '100']
# ['ss54', 'ssh54', '100']
# ['ss55', 'ssh55', '100']
# ['ss56', 'ssh56', '100']
# ['ss57', 'ssh57', '100']
# ['ss58', 'ssh58', '100']
# ['ss59', 'ssh59', '100']
# ['ss60', 'ssh60', '100']
# ['ss61', 'ssh61', '100']
# ['ss62', 'ssh62', '100']
# ['ss63', 'ssh63', '100']
# ['ss64', 'ssh64', '100']
# ['ss65', 'ssh65', '100']
# ['ss66', 'ssh66', '100']
# ['ss67', 'ssh67', '100']
# ['ss68', 'ssh68', '100']
# ['ss69', 'ssh69', '100']
# ['ss70', 'ssh70', '100']
# ['ss71', 'ssh71', '100']
# ['ss72', 'ssh72', '100']
# ['ss73', 'ssh73', '100']
# ['ss74', 'ssh74', '100']
# ['ss75', 'ssh75', '100']
# ['ss76', 'ssh76', '100']
# ['ss77', 'ssh77', '100']
# ['ss78', 'ssh78', '100']
# ['ss79', 'ssh79', '100']
# ['ss80', 'ssh80', '100']
# ['ss81', 'ssh81', '100']
# ['ss82', 'ssh82', '100']
# ['ss83', 'ssh83', '100']
# ['ss84', 'ssh84', '100']
# ['ss85', 'ssh85', '100']
# ['ss86', 'ssh86', '100']
# ['ss87', 'ssh87', '100']
# ['ss88', 'ssh88', '100']
# ['ss89', 'ssh89', '100']
# ['ss90', 'ssh90', '100']
# ['ss91', 'ssh91', '100']
# ['ss92', 'ssh92', '100']
# ['ss93', 'ssh93', '100']
# ['ss94', 'ssh94', '100']
# ['ss95', 'ssh95', '100']
# ['ss96', 'ssh96', '100']
# ['ss97', 'ssh97', '100']
# ['ss98', 'ssh98', '100']
# ['ss99', 'ssh99', '100']
# *** Adding hosts:
# ssh0 ssh1 ssh2 ssh3 ssh4 ssh5 ssh6 ssh7 ssh8 ssh9 ssh10 ssh11 ssh12 ssh13 ssh14 ssh15 ssh16 ssh17 ssh18 ssh19 ssh20 ssh21 ssh22 ssh23 ssh24 ssh25 ssh26 ssh27 ssh28 ssh29 ssh30 ssh31 ssh32 ssh33 ssh34 ssh35 ssh36 ssh37 ssh38 ssh39 ssh40 ssh41 ssh42 ssh43 ssh44 ssh45 ssh46 ssh47 ssh48 ssh49 ssh50 ssh51 ssh52 ssh53 ssh54 ssh55 ssh56 ssh57 ssh58 ssh59 ssh60 ssh61 ssh62 ssh63 ssh64 ssh65 ssh66 ssh67 ssh68 ssh69 ssh70 ssh71 ssh72 ssh73 ssh74 ssh75 ssh76 ssh77 ssh78 ssh79 ssh80 ssh81 ssh82 ssh83 ssh84 ssh85 ssh86 ssh87 ssh88 ssh89 ssh90 ssh91 ssh92 ssh93 ssh94 ssh95 ssh96 ssh97 ssh98 ssh99
# *** Adding switches:
# s0 s1 s2 s3 s4 s5 s6 s7 s8 s9 s10 s11 s12 s13 s14 s15 s16 s17 s18 s19 s20 ss0 ss1 ss2 ss3 ss4 ss5 ss6 ss7 ss8 ss9 ss10 ss11 ss12 ss13 ss14 ss15 ss16 ss17 ss18 ss19 ss20 ss21 ss22 ss23 ss24 ss25 ss26 ss27 ss28 ss29 ss30 ss31 ss32 ss33 ss34 ss35 ss36 ss37 ss38 ss39 ss40 ss41 ss42 ss43 ss44 ss45 ss46 ss47 ss48 ss49 ss50 ss51 ss52 ss53 ss54 ss55 ss56 ss57 ss58 ss59 ss60 ss61 ss62 ss63 ss64 ss65 ss66 ss67 ss68 ss69 ss70 ss71 ss72 ss73 ss74 ss75 ss76 ss77 ss78 ss79 ss80 ss81 ss82 ss83 ss84 ss85 ss86 ss87 ss88 ss89 ss90 ss91 ss92 ss93 ss94 ss95 ss96 ss97 ss98 ss99
# *** Adding links:
# (s0, s1) (s0, s2) (s0, s3) (s0, s5) (s0, ss22) (s0, ss31) (s0, ss97) (s1, s4) (s1, s11) (s1, ss51) (s1, ss65) (s1, ss90) (s2, s10) (s2, s14) (s2, s16) (s4, s6) (s4, s8) (s4, s9) (s4, s10) (s4, s11) (s4, s13) (s4, s16) (s4, s18) (s4, ss31) (s4, ss37) (s4, ss60) (s4, ss77) (s4, ss81) (s5, s7) (s5, ss69) (s6, ss66) (s7, s14) (s7, s15) (s9, s12) (s9, ss57) (s10, s15) (s10, ss23) (s10, ss28) (s10, ss64) (s10, ss82) (s10, ss92) (s10, ss94) (s11, ss25) (s12, ss85) (s13, s18) (s13, ss47) (s13, ss91) (s14, ss21) (s14, ss68) (s15, s17) (s15, s19) (s16, ss73) (s18, s20) (s18, ss87) (s20, ss86) (s20, ss87) (ss0, ssh0) (ss1, ssh1) (ss2, ssh2) (ss3, ssh3) (ss4, ssh4) (ss5, ssh5) (ss6, ssh6) (ss7, ssh7) (ss8, ssh8) (ss9, ssh9) (ss10, ssh10) (ss11, ssh11) (ss12, ssh12) (ss13, ssh13) (ss14, ssh14) (ss15, ssh15) (ss16, ssh16) (ss17, ssh17) (ss18, ssh18) (ss19, ssh19) (ss20, ssh20) (ss21, ss14) (ss21, ss22) (ss21, ss35) (ss21, ss57) (ss21, ss60) (ss21, ss75) (ss21, ss77) (ss21, ss80) (ss21, ss81) (ss21, ss86) (ss21, ss97) (ss21, ssh21) (ss22, ss3) (ss22, ss35) (ss22, ss51) (ss22, ssh22) (ss23, ssh23) (ss24, ssh24) (ss25, ssh25) (ss26, ssh26) (ss27, ssh27) (ss28, ss13) (ss28, ss47) (ss28, ss82) (ss28, ss98) (ss28, ssh28) (ss29, ssh29) (ss30, ssh30) (ss31, ss19) (ss31, ss29) (ss31, ss39) (ss31, ss64) (ss31, ss90) (ss31, ssh31) (ss32, ssh32) (ss33, ssh33) (ss34, ssh34) (ss35, ss14) (ss35, ss16) (ss35, ss32) (ss35, ss44) (ss35, ss78) (ss35, ss98) (ss35, ssh35) (ss36, ssh36) (ss37, ss31) (ss37, ssh37) (ss38, ssh38) (ss39, ss45) (ss39, ssh39) (ss40, ssh40) (ss41, ssh41) (ss42, ssh42) (ss43, ssh43) (ss44, ss83) (ss44, ssh44) (ss45, ss56) (ss45, ss86) (ss45, ssh45) (ss46, ssh46) (ss47, ss61) (ss47, ss82) (ss47, ss95) (ss47, ssh47) (ss48, ssh48) (ss49, ssh49) (ss50, ssh50) (ss51, ss13) (ss51, ss47) (ss51, ss53) (ss51, ss54) (ss51, ss61) (ss51, ss69) (ss51, ss73) (ss51, ss74) (ss51, ss80) (ss51, ss87) (ss51, ss97) (ss51, ss98) (ss51, ssh51) (ss52, ssh52) (ss53, ss0) (ss53, ss13) (ss53, ss18) (ss53, ss64) (ss53, ss67) (ss53, ss70) (ss53, ss74) (ss53, ss83) (ss53, ss85) (ss53, ss88) (ss53, ss93) (ss53, ss97) (ss53, ssh53) (ss54, ss67) (ss54, ssh54) (ss55, ssh55) (ss56, ss27) (ss56, ss38) (ss56, ss43) (ss56, ss63) (ss56, ss66) (ss56, ss90) (ss56, ss97) (ss56, ssh56) (ss57, ss53) (ss57, ss55) (ss57, ss74) (ss57, ssh57) (ss58, ssh58) (ss59, ssh59) (ss60, ss16) (ss60, ss57) (ss60, ssh60) (ss61, ss23) (ss61, ss47) (ss61, ss50) (ss61, ss55) (ss61, ss62) (ss61, ss85) (ss61, ss92) (ss61, ss94) (ss61, ss98) (ss61, ss99) (ss61, ssh61) (ss62, ssh62) (ss63, ss14) (ss63, ss43) (ss63, ss56) (ss63, ss84) (ss63, ssh63) (ss64, ss12) (ss64, ss24) (ss64, ss25) (ss64, ss41) (ss64, ss49) (ss64, ss58) (ss64, ss68) (ss64, ss70) (ss64, ss72) (ss64, ss74) (ss64, ss75) (ss64, ss83) (ss64, ss89) (ss64, ss96) (ss64, ssh64) (ss65, ss9) (ss65, ssh65) (ss66, ss9) (ss66, ss10) (ss66, ss54) (ss66, ss73) (ss66, ss88) (ss66, ssh66) (ss67, ss10) (ss67, ss39) (ss67, ss66) (ss67, ss69) (ss67, ss77) (ss67, ss86) (ss67, ss93) (ss67, ssh67) (ss68, ss71) (ss68, ssh68) (ss69, ss24) (ss69, ss67) (ss69, ss96) (ss69, ssh69) (ss70, ssh70) (ss71, ss85) (ss71, ssh71) (ss72, ss39) (ss72, ssh72) (ss73, ss51) (ss73, ss61) (ss73, ss82) (ss73, ss98) (ss73, ssh73) (ss74, ss3) (ss74, ss26) (ss74, ss37) (ss74, ss43) (ss74, ss53) (ss74, ss57) (ss74, ss82) (ss74, ssh74) (ss75, ss64) (ss75, ssh75) (ss76, ssh76) (ss77, ss19) (ss77, ss21) (ss77, ss31) (ss77, ss33) (ss77, ss35) (ss77, ss37) (ss77, ss38) (ss77, ss54) (ss77, ss56) (ss77, ss62) (ss77, ss63) (ss77, ss67) (ss77, ss80) (ss77, ss81) (ss77, ss82) (ss77, ss94) (ss77, ssh77) (ss78, ss17) (ss78, ss33) (ss78, ss65) (ss78, ss66) (ss78, ss85) (ss78, ssh78) (ss79, ssh79) (ss80, ss57) (ss80, ss76) (ss80, ssh80) (ss81, ss2) (ss81, ss14) (ss81, ss38) (ss81, ss43) (ss81, ss67) (ss81, ss73) (ss81, ss76) (ss81, ss77) (ss81, ss78) (ss81, ss93) (ss81, ss95) (ss81, ss97) (ss81, ssh81) (ss82, ss16) (ss82, ss40) (ss82, ss41) (ss82, ss42) (ss82, ss43) (ss82, ss47) (ss82, ss52) ( ...
# *** Configuring hosts
# ssh0 ssh1 ssh2 ssh3 ssh4 ssh5 ssh6 ssh7 ssh8 ssh9 ssh10 ssh11 ssh12 ssh13 ssh14 ssh15 ssh16 ssh17 ssh18 ssh19 ssh20 ssh21 ssh22 ssh23 ssh24 ssh25 ssh26 ssh27 ssh28 ssh29 ssh30 ssh31 ssh32 ssh33 ssh34 ssh35 ssh36 ssh37 ssh38 ssh39 ssh40 ssh41 ssh42 ssh43 ssh44 ssh45 ssh46 ssh47 ssh48 ssh49 ssh50 ssh51 ssh52 ssh53 ssh54 ssh55 ssh56 ssh57 ssh58 ssh59 ssh60 ssh61 ssh62 ssh63 ssh64 ssh65 ssh66 ssh67 ssh68 ssh69 ssh70 ssh71 ssh72 ssh73 ssh74 ssh75 ssh76 ssh77 ssh78 ssh79 ssh80 ssh81 ssh82 ssh83 ssh84 ssh85 ssh86 ssh87 ssh88 ssh89 ssh90 ssh91 ssh92 ssh93 ssh94 ssh95 ssh96 ssh97 ssh98 ssh99
# *** Starting controller
# c0
# *** Starting 121 switches
# s0 s1 s2 s3 s4 s5 s6 s7 s8 s9 s10 s11 s12 s13 s14 s15 s16 s17 s18 s19 s20 ss0 ss1 ss2 ss3 ss4 ss5 ss6 ss7 ss8 ss9 ss10 ss11 ss12 ss13 ss14 ss15 ss16 ss17 ss18 ss19 ss20 ss21 ss22 ss23 ss24 ss25 ss26 ss27 ss28 ss29 ss30 ss31 ss32 ss33 ss34 ss35 ss36 ss37 ss38 ss39 ss40 ss41 ss42 ss43 ss44 ss45 ss46 ss47 ss48 ss49 ss50 ss51 ss52 ss53 ss54 ss55 ss56 ss57 ss58 ss59 ss60 ss61 ss62 ss63 ss64 ss65 ss66 ss67 ss68 ss69 ss70 ss71 ss72 ss73 ss74 ss75 ss76 ss77 ss78 ss79 ss80 ss81 ss82 ss83 ss84 ss85 ss86 ss87 ss88 ss89 ss90 ss91 ss92 ss93 ss94 ss95 ss96 ss97 ss98 ss99 ...
# *** Starting CLI:
# mininet> s0 ping s1 -c 1
# PING 127.0.0.1 (127.0.0.1) 56(84) bytes of data.
# 64 bytes from 127.0.0.1: icmp_seq=1 ttl=64 time=0.032 ms
#
# --- 127.0.0.1 ping statistics ---
# 1 packets transmitted, 1 received, 0% packet loss, time 0ms
# rtt min/avg/max/mdev = 0.032/0.032/0.032/0.000 ms
# mininet> ss90 ping ss79 -c 1
# PING 127.0.0.1 (127.0.0.1) 56(84) bytes of data.
# 64 bytes from 127.0.0.1: icmp_seq=1 ttl=64 time=0.054 ms
#
# --- 127.0.0.1 ping statistics ---
# 1 packets transmitted, 1 received, 0% packet loss, time 0ms
# rtt min/avg/max/mdev = 0.054/0.054/0.054/0.000 ms
# mininet> s0 ping ss90 -c 1
# PING 127.0.0.1 (127.0.0.1) 56(84) bytes of data.
# 64 bytes from 127.0.0.1: icmp_seq=1 ttl=64 time=0.041 ms
#
# --- 127.0.0.1 ping statistics ---
# 1 packets transmitted, 1 received, 0% packet loss, time 0ms
# rtt min/avg/max/mdev = 0.041/0.041/0.041/0.000 ms
# mininet> ss97 ping ss93 -c 1
# PING 127.0.0.1 (127.0.0.1) 56(84) bytes of data.
# 64 bytes from 127.0.0.1: icmp_seq=1 ttl=64 time=0.029 ms
#
# --- 127.0.0.1 ping statistics ---
# 1 packets transmitted, 1 received, 0% packet loss, time 0ms
# rtt min/avg/max/mdev = 0.029/0.029/0.029/0.000 ms
# mininet> ss99 ping ssh99 -c 1
# PING 10.0.0.100 (10.0.0.100) 56(84) bytes of data.
#
# --- 10.0.0.100 ping statistics ---
# 1 packets transmitted, 0 received, 100% packet loss, time 0ms
# mininet> pingall
# *** Ping: testing ping reachability
# ssh0 -> X X X X X X X X X X
